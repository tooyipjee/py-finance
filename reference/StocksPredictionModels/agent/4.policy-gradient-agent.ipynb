# %%
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# WARNING:tensorflow:From C:\Users\Jason\anaconda3\envs\py-finance\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
class Agent:

    LEARNING_RATE = 1e-4
    LAYER_SIZE = 256
    GAMMA = 0.9
    OUTPUT_SIZE = 3

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.REWARDS = tf.placeholder(tf.float32, (None))
        self.ACTIONS = tf.placeholder(tf.int32, (None))
        feed_forward = tf.layers.dense(self.X, self.LAYER_SIZE, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, self.OUTPUT_SIZE, activation = tf.nn.softmax)
        input_y = tf.one_hot(self.ACTIONS, self.OUTPUT_SIZE)
        loglike = tf.log((input_y * (input_y - self.logits) + (1 - input_y) * (input_y + self.logits)) + 1)
        rewards = tf.tile(tf.reshape(self.REWARDS, (-1,1)), [1, self.OUTPUT_SIZE])
        self.cost = -tf.reduce_mean(loglike * (rewards + 1)) 
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def discount_rewards(self, r):
        discounted_r = np.zeros_like(r)
        running_add = 0
        for t in reversed(range(0, r.size)):
            running_add = running_add * self.GAMMA + r[t]
            discounted_r[t] = running_add
        return discounted_r
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.get_predicted_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            ep_history = []
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.get_predicted_action(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= close[t]
                
                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                ep_history.append([state,action,starting_money,next_state])
                state = next_state
            ep_history = np.array(ep_history)
            ep_history[:,2] = self.discount_rewards(ep_history[:,2])
            cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict={self.X:np.vstack(ep_history[:,0]),
                                                    self.REWARDS:ep_history[:,2],
                                                    self.ACTIONS:ep_history[:,1]})
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
agent = Agent(state_size = window_size,
             window_size = window_size,
             trend = close,
             skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-7-46892b33829f>:17: dense (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From C:\Users\Jason\anaconda3\envs\py-finance\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# <ipython-input-7-46892b33829f>:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   ep_history = np.array(ep_history)
# epoch: 10, total rewards: 83.939937.3, cost: -6345.455078, total money: 3473.109921
# epoch: 20, total rewards: 385.170102.3, cost: -6115.309570, total money: 1959.020077
# epoch: 30, total rewards: 421.460143.3, cost: -6634.758301, total money: 1979.180175
# epoch: 40, total rewards: 866.045101.3, cost: -5696.911133, total money: 2416.735104
# epoch: 50, total rewards: 532.170042.3, cost: -7411.213867, total money: 2072.690001
# epoch: 60, total rewards: 1870.775023.3, cost: -3291.822021, total money: 2495.335021
# epoch: 70, total rewards: 1647.674921.3, cost: -4994.923828, total money: 3209.164912
# epoch: 80, total rewards: 1774.585020.3, cost: -4098.009277, total money: 3297.855040
# epoch: 90, total rewards: 1349.095210.3, cost: -5862.595703, total money: 1988.065181
# epoch: 100, total rewards: 1840.350214.3, cost: -3549.949219, total money: 2510.760188
# epoch: 110, total rewards: 1859.630122.3, cost: -3752.600830, total money: 2478.040095
# epoch: 120, total rewards: 1718.704893.3, cost: -4475.559570, total money: 2366.324888
# epoch: 130, total rewards: 1640.519954.3, cost: -4110.559570, total money: 1335.539973
# epoch: 140, total rewards: 909.085082.3, cost: -10162.923828, total money: 1545.755064
# epoch: 150, total rewards: 1447.394957.3, cost: -6698.908203, total money: 2069.344908
# epoch: 160, total rewards: 2060.674985.3, cost: -2655.767334, total money: 3621.725034
# epoch: 170, total rewards: 1584.720089.3, cost: -4516.868652, total money: 1342.249996
# epoch: 180, total rewards: 1452.299924.3, cost: -5620.143555, total money: 1150.429929
# epoch: 190, total rewards: 1374.839961.3, cost: -7769.706055, total money: 1981.159908
# epoch: 200, total rewards: 1779.730040.3, cost: -4341.381836, total money: 1488.400023

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 3: buy 1 unit at price 782.520020, total balance 9217.479980
# day 4: buy 1 unit at price 790.510010, total balance 8426.969970
# day 5, sell 1 unit at price 785.309998, investment 0.356538 %, total balance 9212.279968,
# day 6: buy 1 unit at price 762.559998, total balance 8449.719970
# day 13, sell 1 unit at price 769.200012, investment -2.695728 %, total balance 9218.919982,
# day 15: buy 1 unit at price 760.989990, total balance 8457.929992
# day 16: buy 1 unit at price 761.679993, total balance 7696.249999
# day 17: buy 1 unit at price 768.239990, total balance 6928.010009
# day 18: buy 1 unit at price 770.840027, total balance 6157.169982
# day 19, sell 1 unit at price 758.039978, investment -0.592743 %, total balance 6915.209960,
# day 20: buy 1 unit at price 747.919983, total balance 6167.289977
# day 21, sell 1 unit at price 750.500000, investment -1.378466 %, total balance 6917.789977,
# day 23, sell 1 unit at price 759.109985, investment -0.337413 %, total balance 7676.899962,
# day 25, sell 1 unit at price 776.419983, investment 1.064771 %, total balance 8453.319945,
# day 27: buy 1 unit at price 789.270020, total balance 7664.049925
# day 30: buy 1 unit at price 797.849976, total balance 6866.199949
# day 31, sell 1 unit at price 790.799988, investment 2.589378 %, total balance 7656.999937,
# day 32: buy 1 unit at price 794.200012, total balance 6862.799925
# day 33, sell 1 unit at price 796.419983, investment 6.484651 %, total balance 7659.219908,
# day 34: buy 1 unit at price 794.559998, total balance 6864.659910
# day 35: buy 1 unit at price 791.260010, total balance 6073.399900
# day 38, sell 1 unit at price 785.049988, investment -0.534675 %, total balance 6858.449888,
# day 42, sell 1 unit at price 786.900024, investment -1.372432 %, total balance 7645.349912,
# day 43: buy 1 unit at price 794.020020, total balance 6851.329892
# day 46, sell 1 unit at price 804.789978, investment 1.333413 %, total balance 7656.119870,
# day 47: buy 1 unit at price 807.909973, total balance 6848.209897
# day 49: buy 1 unit at price 807.880005, total balance 6040.329892
# day 51: buy 1 unit at price 806.070007, total balance 5234.259885
# day 53, sell 1 unit at price 805.020020, investment 1.316455 %, total balance 6039.279905,
# day 54: buy 1 unit at price 819.309998, total balance 5219.969907
# day 55: buy 1 unit at price 823.869995, total balance 4396.099912
# day 59, sell 1 unit at price 802.320007, investment 1.397770 %, total balance 5198.419919,
# day 61: buy 1 unit at price 795.695007, total balance 4402.724912
# day 63: buy 1 unit at price 801.489990, total balance 3601.234922
# day 64, sell 1 unit at price 801.340027, investment 0.921892 %, total balance 4402.574949,
# day 65, sell 1 unit at price 806.969971, investment -0.116350 %, total balance 5209.544920,
# day 69: buy 1 unit at price 819.239990, total balance 4390.304930
# day 73, sell 1 unit at price 828.070007, investment 2.499134 %, total balance 5218.374937,
# day 74: buy 1 unit at price 831.659973, total balance 4386.714964
# day 75: buy 1 unit at price 830.760010, total balance 3555.954954
# day 76: buy 1 unit at price 831.330017, total balance 2724.624937
# day 77: buy 1 unit at price 828.640015, total balance 1895.984922
# day 78, sell 1 unit at price 829.280029, investment 2.879405 %, total balance 2725.264951,
# day 80: buy 1 unit at price 835.239990, total balance 1890.024961
# day 82, sell 1 unit at price 829.080017, investment 1.192469 %, total balance 2719.104978,
# day 84: buy 1 unit at price 831.909973, total balance 1887.195005
# day 85, sell 1 unit at price 835.369995, investment 1.395851 %, total balance 2722.565000,
# day 86: buy 1 unit at price 838.679993, total balance 1883.885007
# day 87, sell 1 unit at price 843.250000, investment 5.976535 %, total balance 2727.135007,
# day 89: buy 1 unit at price 845.619995, total balance 1881.515012
# day 94: buy 1 unit at price 830.460022, total balance 1051.054990
# day 95: buy 1 unit at price 829.590027, total balance 221.464963
# day 98, sell 1 unit at price 819.510010, investment 2.248315 %, total balance 1040.974973,
# day 104, sell 1 unit at price 834.570007, investment 1.871249 %, total balance 1875.544980,
# day 105: buy 1 unit at price 831.409973, total balance 1044.135007
# day 107, sell 1 unit at price 824.669983, investment -0.840487 %, total balance 1868.804990,
# day 108: buy 1 unit at price 824.729980, total balance 1044.075010
# day 109: buy 1 unit at price 823.349976, total balance 220.725034
# day 110, sell 1 unit at price 824.320007, investment -0.775194 %, total balance 1045.045041,
# day 112, sell 1 unit at price 837.169983, investment 0.702485 %, total balance 1882.215024,
# day 113: buy 1 unit at price 836.820007, total balance 1045.395017
# day 114: buy 1 unit at price 838.210022, total balance 207.184995
# day 123, sell 1 unit at price 916.440002, investment 10.595673 %, total balance 1123.624997,
# day 124, sell 1 unit at price 927.039978, investment 10.990852 %, total balance 2050.664975,
# day 125: buy 1 unit at price 931.659973, total balance 1119.005002
# day 128, sell 1 unit at price 932.169983, investment 12.051786 %, total balance 2051.174985,
# day 129: buy 1 unit at price 928.780029, total balance 1122.394956
# day 130, sell 1 unit at price 930.599976, investment 10.960078 %, total balance 2052.994932,
# day 131: buy 1 unit at price 932.219971, total balance 1120.774961
# day 134: buy 1 unit at price 919.619995, total balance 201.154966
# day 142, sell 1 unit at price 975.880005, investment 15.404083 %, total balance 1177.034971,
# day 145: buy 1 unit at price 975.599976, total balance 201.434995
# day 147, sell 1 unit at price 976.570007, investment 17.593861 %, total balance 1178.005002,
# day 153: buy 1 unit at price 950.760010, total balance 227.244992
# day 155, sell 1 unit at price 939.780029, investment 13.282465 %, total balance 1167.025021,
# day 156: buy 1 unit at price 957.369995, total balance 209.655026
# day 160, sell 1 unit at price 965.590027, investment 16.138855 %, total balance 1175.245053,
# day 161: buy 1 unit at price 952.270020, total balance 222.975033
# day 164, sell 1 unit at price 917.789978, investment 11.283693 %, total balance 1140.765011,
# day 165, sell 1 unit at price 908.729980, investment 10.369831 %, total balance 2049.494991,
# day 168: buy 1 unit at price 906.690002, total balance 1142.804989
# day 169: buy 1 unit at price 918.590027, total balance 224.214962
# day 178, sell 1 unit at price 968.150024, investment 15.693938 %, total balance 1192.364986,
# day 179: buy 1 unit at price 972.919983, total balance 219.445003
# day 185, sell 1 unit at price 930.500000, investment 11.010364 %, total balance 1149.945003,
# day 188, sell 1 unit at price 923.650024, investment -0.859750 %, total balance 2073.595027,
# day 189: buy 1 unit at price 927.960022, total balance 1145.635005
# day 190: buy 1 unit at price 929.359985, total balance 216.275020
# day 191, sell 1 unit at price 926.789978, investment -0.214265 %, total balance 1143.064998,
# day 192: buy 1 unit at price 922.900024, total balance 220.164974
# day 193, sell 1 unit at price 907.239990, investment -2.679623 %, total balance 1127.404964,
# day 194, sell 1 unit at price 914.390015, investment -0.568711 %, total balance 2041.794979,
# day 196, sell 1 unit at price 922.219971, investment -5.471505 %, total balance 2964.014950,
# day 197: buy 1 unit at price 926.960022, total balance 2037.054928
# day 199: buy 1 unit at price 910.669983, total balance 1126.384945
# day 202, sell 1 unit at price 927.000000, investment -2.499054 %, total balance 2053.384945,
# day 206, sell 1 unit at price 921.289978, investment -3.768660 %, total balance 2974.674923,
# day 207, sell 1 unit at price 929.570007, investment -2.383779 %, total balance 3904.244930,
# day 208: buy 1 unit at price 939.330017, total balance 2964.914913
# day 209: buy 1 unit at price 937.340027, total balance 2027.574886
# day 210: buy 1 unit at price 928.450012, total balance 1099.124874
# day 212, sell 1 unit at price 935.950012, investment 3.227124 %, total balance 2035.074886,
# day 213: buy 1 unit at price 926.500000, total balance 1108.574886
# day 214, sell 1 unit at price 929.080017, investment 1.141966 %, total balance 2037.654903,
# day 215: buy 1 unit at price 932.070007, total balance 1105.584896
# day 219: buy 1 unit at price 915.000000, total balance 190.584896
# day 224, sell 1 unit at price 920.969971, investment -5.339598 %, total balance 1111.554867,
# day 225, sell 1 unit at price 924.859985, investment -0.334070 %, total balance 2036.414852,
# day 226: buy 1 unit at price 944.489990, total balance 1091.924862
# day 228: buy 1 unit at price 959.109985, total balance 132.814877
# day 230, sell 1 unit at price 957.789978, investment 3.059094 %, total balance 1090.604855,
# day 232, sell 1 unit at price 969.960022, investment 5.099144 %, total balance 2060.564877,
# day 236: buy 1 unit at price 989.250000, total balance 1071.314877
# day 238, sell 1 unit at price 989.679993, investment 6.766200 %, total balance 2060.994870,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
